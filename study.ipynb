# %%
import CFunctions

# %%
import numpy as np

# %%
vect_x = np.arange(10,1000,2)
vect_y = np.arange(3025,5500,5)

# %%
a = CFunctions.area(vect_x, vect_y)
a
# Out:
# 4208880.0

# %% [markdown]
# Shannon Entropy Curve <br>
# Equal probabilities = max entropy <br>
# ![Alt text](image.png)

# %%
se = CFunctions.shannon_entropy(vect_x/np.max(vect_x))
se
# Out:
# array([0.08092596, 0.0939309 , 0.10644586, 0.11854051, 0.13026692,
#        0.14166552, 0.15276861, 0.16360258, 0.17418941, 0.18454766,
#        0.19469327, 0.20464001, 0.21439996, 0.22398373, 0.2334008 ,
#        0.2426596 , 0.25176775, 0.26073212, 0.26955897, 0.278254  ,
#        0.28682245, 0.29526912, 0.30359845, 0.31181455, 0.31992123,
#        0.32792204, 0.33582031, 0.34361911, 0.35132136, 0.35892978,
#        0.36644693, 0.37387524, 0.38121698, 0.38847432, 0.39564929,
#        0.40274384, 0.4097598 , 0.41669892, 0.42356288, 0.43035325,
#        0.43707155, 0.44371923, 0.45029767, 0.4568082 , 0.46325208,
#        0.46963053, 0.47594471, 0.48219574, 0.4883847 , 0.49451263,
#        0.50058052, 0.50658932, 0.51253997, 0.51843335, 0.52427033,
#        0.53005173, 0.53577835, 0.54145098, 0.54707035, 0.5526372 ,
#        0.55815223, 0.56361612, 0.56902952, 0.57439307, 0.5797074 ,
#        0.5849731 , 0.59019076, 0.59536095, 0.6004842 , 0.60556106,
# ...

# %%
CFunctions.logloss(se,se*0.5)
# Out:
# c:\Users\ferna\Documents\rep\ml_libs\CFunctions.py:92: RuntimeWarning: divide by zero encountered in log
# 0.4714969502536934
